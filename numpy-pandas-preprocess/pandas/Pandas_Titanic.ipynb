# %%
import pandas as pd

# %%
df1 = pd.read_csv("../../data/titanic 1.csv")
df2 = pd.read_csv("../../data/titanic 2.csv")

# %% [markdown]
# **1. Mostrar las estadisticas de cada uno de los dataframe**

# %%
df1
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 4 columns]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass            Ticket     Fare
# 0              1         0       3         A/5 21171   7.2500
# 1              2         1       1          PC 17599  71.2833
# 2              3         1       3  STON/O2. 3101282   7.9250
# 3              4         1       1            113803  53.1000
# 4              5         0       3            373450   8.0500
# ..           ...       ...     ...               ...      ...
# 886          887         0       2            211536  13.0000
# 887          888         1       1            112053  30.0000
# 888          889         0       3        W./C. 6607  23.4500
# 889          890         1       1            111369  30.0000
# 890          891         0       3            370376   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# **1. Unir los dataframe para obtener solo uno**

# %%
df = pd.concat([df1, df2], axis=1)
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  PassengerId  Survived  Pclass            Ticket     Fare
# 0    22.0            1         0       3         A/5 21171   7.2500
# 1    38.0            2         1       1          PC 17599  71.2833
# 2    26.0            3         1       3  STON/O2. 3101282   7.9250
# 3    35.0            4         1       1            113803  53.1000
# 4    35.0            5         0       3            373450   8.0500
# ..    ...          ...       ...     ...               ...      ...
# 886  27.0          887         0       2            211536  13.0000
# 887  19.0          888         1       1            112053  30.0000
# 888   NaN          889         0       3        W./C. 6607  23.4500
# 889  26.0          890         1       1            111369  30.0000
# 890  32.0          891         0       3            370376   7.7500
#
# [891 rows x 9 columns]

# %% [markdown]
# **2. Imprimir las últimas 5 filas de las columnas de nombre y edad**

# %%
df.loc[:, ['Name', 'Age']].tail(5)
# Out:
#                                          Name   Age
# 886                     Montvila, Rev. Juozas  27.0
# 887              Graham, Miss. Margaret Edith  19.0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                     Behr, Mr. Karl Howell  26.0
# 890                       Dooley, Mr. Patrick  32.0

# %% [markdown]
# **3. Imprimir las primeras 10 filas de las instancias que en sexo sean igual a femenino**

# %%
df.loc[df['Sex'] == 'female'].head(5)
# Out:
#    PassengerId                                               Name     Sex  \
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8            9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9           10                Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  PassengerId  Survived  Pclass            Ticket     Fare
# 1  38.0            2         1       1          PC 17599  71.2833
# 2  26.0            3         1       3  STON/O2. 3101282   7.9250
# 3  35.0            4         1       1            113803  53.1000
# 8  27.0            9         1       3            347742  11.1333
# 9  14.0           10         1       2            237736  30.0708

# %% [markdown]
# **4. Imprimir las instancias que en la columna Fare sean menor a 33 y en la columna Pclass igual a 2**

# %%
df_fare_pclass= df.loc[ (df['Fare'] < 33) & (df['Pclass'] == 2)]
df_fare_pclass
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 9             10           Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 15            16              Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17            18                  Williams, Mr. Charles Eugene    male   NaN
# 20            21                          Fynney, Mr. Joseph J    male  35.0
# 21            22                         Beesley, Mr. Lawrence    male  34.0
# ..           ...                                           ...     ...   ...
# 866          867                  Duran y More, Miss. Asuncion  female  27.0
# 874          875         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 880          881  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 883          884                 Banfield, Mr. Frederick James    male  28.0
# 886          887                         Montvila, Rev. Juozas    male  27.0
#
#      PassengerId  Survived  Pclass            Ticket     Fare
# 9             10         1       2            237736  30.0708
# 15            16         1       2            248706  16.0000
# 17            18         1       2            244373  13.0000
# 20            21         0       2            239865  26.0000
# 21            22         1       2            248698  13.0000
# ..           ...       ...     ...               ...      ...
# 866          867         1       2     SC/PARIS 2149  13.8583
# 874          875         1       2         P/PP 3381  24.0000
# 880          881         1       2            230433  26.0000
# 883          884         0       2  C.A./SOTON 34068  10.5000
# 886          887         0       2            211536  13.0000
#
# [163 rows x 9 columns]

# %% [markdown]
# **5. Del resultado anterior obten el número de hombres y el número de mujeres**

# %%
#df_fare_pclass_hombre = len(df_fare_pclass.loc[df_fare_pclass['Sex'] == 'men'])
#df_fare_pclass_mujer = len(df_fare_pclass.loc[df_fare_pclass['Sex'] == 'female'])
#print(df_fare_pclass_hombre)
#print(df_fare_pclass_mujer)
df.groupby('Sex')['Fare'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Fare, dtype: int64

# %% [markdown]
# **6. Obten el costo total de los tickets de hombres y el costo total de los tickets de mujeres**

# %%
df.groupby('Sex')['Fare'].sum()
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %% [markdown]
# **7. Obten el costo total de los tickets por cada clase (1, 2 y 3) y el número de pasajeros de cada clase**

# %%
class_stats = df.groupby('Pclass').agg(
    total_fare=('Fare', 'sum'),
    passenger_count=('PassengerId', 'count')
)  

print(class_stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zw/c6nvxs_50p7603nxw86mkjf40000gn/T/ipykernel_57296/1061895797.py in ?()
# ----> 1 class_stats = df.groupby('Pclass').agg(
#       2     total_fare=('Fare', 'sum'),
#       3     passenger_count=('PassengerId', 'count')
#       4 )
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#    1428             kwargs["engine"] = engine
#    1429             kwargs["engine_kwargs"] = engine_kwargs
#    1430
#    1431         op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432         result = op.agg()
#    1433         if not is_dict_like(func) and result is not None:
#    1434             # GH #52849
#    1435             if not self.as_index and is_list_like(func):
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py in ?(self)
#     186         if isinstance(func, str):
#     187             return self.apply_str()
#     188
#     189         if is_dict_like(func):
# --> 190             return self.agg_dict_like()
#     191         elif is_list_like(func):
#     192             # we require a list, but not a 'str'
#     193             return self.agg_list_like()
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py in ?(self)
#     419         Returns
#     420         -------
#     421         Result of aggregation.
#     422         """
# --> 423         return self.agg_or_apply_dict_like(op_name="agg")
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py in ?(self, op_name)
#    1604
#    1605         with com.temp_setattr(
#    1606             obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607         ):
# -> 1608             result_index, result_data = self.compute_dict_like(
#    1609                 op_name, selected_obj, selection, kwargs
#    1610             )
#    1611         result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py in ?(self, op_name, selected_obj, selection, kwargs)
#     492                 keys += [key] * len(key_data)
#     493                 results += key_data
#     494         else:
#     495             # key used for column selection and output
# --> 496             results = [
#     497                 getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498                 for key, how in func.items()
#     499             ]
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#     253             # but not the class list / tuple itself.
#     254             func = maybe_mangle_lambdas(func)
#     255             kwargs["engine"] = engine
#     256             kwargs["engine_kwargs"] = engine_kwargs
# --> 257             ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258             if relabeling:
#     259                 # columns is not narrowed by mypy from relabeling flag
#     260                 assert columns is not None  # for mypy
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, arg, *args, **kwargs)
#     358             # Combine results using the index, need to adjust index after
#     359             # if as_index=False (GH#50724)
#     360             for idx, (name, func) in enumerate(arg):
#     361                 key = base.OutputKey(label=name, position=idx)
# --> 362                 results[key] = self.aggregate(func, *args, **kwargs)
#     363
#     364         if any(isinstance(x, DataFrame) for x in results.values()):
#     365             from pandas import concat
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, func, engine, engine_kwargs, *args, **kwargs)
#     245                 # numba is requested via the global option)
#     246                 kwargs["engine"] = engine
#     247             if engine_kwargs is not None:
#     248                 kwargs["engine_kwargs"] = engine_kwargs
# --> 249             return getattr(self, func)(*args, **kwargs)
#     250
#     251         elif isinstance(func, abc.Iterable):
#     252             # Catch instances of lists / tuples
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py in ?(self)
#    2350                 return counted[0]
#    2351             return counted
#    2352
#    2353         new_mgr = data.grouped_reduce(hfunc)
# -> 2354         new_obj = self._wrap_agged_manager(new_mgr)
#    2355
#    2356         # If we are grouping on categoricals we want unobserved categories to
#    2357         # return zero, rather than the default of NaN which the reindexing in
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py in ?(self, mgr)
#     155     def _wrap_agged_manager(self, mgr: Manager) -> Series:
#     156         out = self.obj._constructor_from_mgr(mgr, axes=mgr.axes)
# --> 157         out._name = self.obj.name
#     158         return out
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %% [markdown]
# **8. Crear una columna con el apellido de cada pasajero y agregala al dataframe**

# %%
df['last name'] = df['Name'].apply(lambda x: x.split(',')[0])
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  PassengerId  Survived  Pclass            Ticket     Fare  last name
# 0    22.0            1         0       3         A/5 21171   7.2500     Braund
# 1    38.0            2         1       1          PC 17599  71.2833    Cumings
# 2    26.0            3         1       3  STON/O2. 3101282   7.9250  Heikkinen
# 3    35.0            4         1       1            113803  53.1000   Futrelle
# 4    35.0            5         0       3            373450   8.0500      Allen
# ..    ...          ...       ...     ...               ...      ...        ...
# 886  27.0          887         0       2            211536  13.0000   Montvila
# 887  19.0          888         1       1            112053  30.0000     Graham
# 888   NaN          889         0       3        W./C. 6607  23.4500   Johnston
# 889  26.0          890         1       1            111369  30.0000       Behr
# 890  32.0          891         0       3            370376   7.7500     Dooley
#
# [891 rows x 10 columns]

# %% [markdown]
# **9. Encuentra si se repiten apellidos en la columna que se creo en el ejercicio anterior**

# %%
duplicate_last_names = df[df.duplicated('last name', keep=False)]['last name'].unique()
duplicate_last_names
# Out:
# array(['Braund', 'Futrelle', 'Allen', 'Moran', 'Palsson', 'Johnson',
#        'Nasser', 'Sandstrom', 'Andersson', 'Rice', 'Williams',
#        'Vander Planke', 'Asplund', 'Fortune', 'Meyer', 'Holverson',
#        'Nicola-Yarred', 'Turpin', 'Laroche', 'Arnold-Franchi', 'Panula',
#        'Harper', 'West', 'Goodwin', 'Harris', 'Skoog', 'Moubarek',
#        'Caldwell', 'Backstrom', 'Ford', 'Dean', 'Doling', 'Kantor',
#        'Petroff', 'White', 'Johansson', 'Gustafsson', 'Zabour', 'Jussila',
#        'Attalah', 'Baxter', 'Hickman', 'Webber', 'Peter', 'Boulos',
#        'Hakkarainen', 'Navratil', 'Pears', 'Olsen', 'Sage', 'Calic',
#        'Goldsmith', 'Smith', 'Lefebre', 'Becker', "O'Brien", 'Bourke',
#        'Brown', 'Strom', 'Ali', 'Newell', 'Jacobsohn', 'Hoyt', 'Larsson',
#        'Collyer', 'Murphy', 'Minahan', 'Hamalainen', 'Beckwith', 'Carter',
#        'Lobb', 'Rosblom', 'Taussig', 'Graham', 'Mellinger', 'Andrews',
#        'Abbott', 'Olsson', 'Bishop', 'Allison', 'Kelly', 'McCoy', 'Keane',
#        'Penasco y Castellana', 'Abelson', 'Hays', 'Ryerson', 'Hart',
#        'Wick', 'Hippach', 'Frauenthal', 'Coutts', 'Elias', 'Barbara',
#        'Nakid', 'Davies', 'Oreskovic', 'Richards', 'Van Impe', 'Danbom',
#        'Flynn', 'Thorneycroft', 'Silvey', 'Baclini', 'Hagland',
#        'Goldenberg', 'Morley', 'Cacic', 'Renouf', 'Stanley', 'Svensson',
#        'Quick', 'Daly', 'Coleff', 'Hocking', 'Crosby', 'Beane', 'Thayer',
#        'Duff Gordon', 'Chapman', 'Herman', 'Yasbeck', 'Hansen', 'Jensen',
#        'Taylor', 'Dick', 'Lam', 'Saad', 'Chambers', 'Moor', 'Carlsson',
#        'Johnston', 'Mallet'], dtype=object)

# %% [markdown]
# **10. Encuentra los apellidos que se repiten en la columna recien creada**

# %%
repeated_last_names = df['last name'].value_counts()[df['last name'].value_counts() > 1]
repeated_last_names
# Out:
# last name
# Andersson    9
# Sage         7
# Panula       6
# Skoog        6
# Carter       6
#             ..
# Hocking      2
# Kantor       2
# Petroff      2
# Johnston     2
# Dean         2
# Name: count, Length: 133, dtype: int64

# %% [markdown]
# **11. Imprime los primeros 10 pasajeros que tengan un PassengerID multiplo de 3**

# %%
df[df['PassengerId'] % 3 == 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df[df['PassengerId'] % 3 == 0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4089, in DataFrame.__getitem__(self, key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
# -> 4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:10984, in NDFrame.where(self, cond, other, inplace, axis, level)
#   10977             warnings.warn(
#   10978                 _chained_assignment_warning_method_msg,
#   10979                 FutureWarning,
#   10980                 stacklevel=2,
#   10981             )
#   10983 other = common.apply_if_callable(other, self)
# > 10984 return self._where(cond, other, inplace, axis, level)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:10685, in NDFrame._where(self, cond, other, inplace, axis, level, warn)
#   10682     cond = cond.astype(bool)
#   10684 cond = -cond if inplace else cond
# > 10685 cond = cond.reindex(self._info_axis, axis=self._info_axis_number, copy=False)
#   10687 # try to align with other
#   10688 if isinstance(other, NDFrame):
#   10689     # align with me
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5378, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5359 @doc(
#    5360     NDFrame.reindex,
#    5361     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5376     tolerance=None,
#    5377 ) -> DataFrame:
# -> 5378     return super().reindex(
#    5379         labels=labels,
#    5380         index=index,
#    5381         columns=columns,
#    5382         axis=axis,
#    5383         method=method,
#    5384         copy=copy,
#    5385         level=level,
#    5386         fill_value=fill_value,
#    5387         limit=limit,
#    5388         tolerance=tolerance,
#    5389     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:5610, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5607     return self._reindex_multi(axes, copy, fill_value)
#    5609 # perform the reindex on the axes
# -> 5610 return self._reindex_axes(
#    5611     axes, level, limit, tolerance, method, fill_value, copy
#    5612 ).__finalize__(self, method="reindex")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:5633, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5630     continue
#    5632 ax = self._get_axis(a)
# -> 5633 new_index, indexer = ax.reindex(
#    5634     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635 )
#    5637 axis = self._get_axis_number(a)
#    5638 obj = obj._reindex_with_indexers(
#    5639     {axis: [new_index, indexer]},
#    5640     fill_value=fill_value,
#    5641     copy=copy,
#    5642     allow_dups=False,
#    5643 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:4429, in Index.reindex(self, target, method, level, limit, tolerance)
#    4426     raise ValueError("cannot handle a non-unique multi-index!")
#    4427 elif not self.is_unique:
#    4428     # GH#42568
# -> 4429     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4430 else:
#    4431     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# **12. ¿Cuales son los apellidos de los pasajeros que son mujeres y menores de 20 años?**

# %%
df[(df['Age'] < 20) & (df['Sex'] == 'female')]['last name'].unique()
# Out:
# array(['Nasser', 'Sandstrom', 'Vestrom', 'McGowan', 'Palsson',
#        'Vander Planke', 'Nicola-Yarred', 'Laroche', 'Devaney',
#        'Arnold-Franchi', 'West', 'Andersson', 'Goodwin', 'Ilett',
#        'Zabour', 'Attalah', 'Newsom', 'Ford', 'Gilnagh', 'Johnson',
#        'Kink-Heilmann', 'Andersen-Jensen', 'Strom', 'Carr', 'Asplund',
#        'Collyer', 'Bishop', 'Allison', 'Penasco y Castellana', 'Ryerson',
#        'Hippach', 'Nakid', 'Lehmann', 'Silven', 'Van Impe', 'Phillips',
#        'Carter', 'Mellinger', 'Baclini', 'Hirvonen', 'Maioni', 'Quick',
#        'Hart', 'Beane', 'Taussig', 'Becker', 'Skoog', 'Doling', 'Hegarty',
#        'Turja', 'Madill', 'Karun', 'Astor', 'Barbara', 'Harper', 'Wells',
#        'Emanuel', 'Ayoub', 'Dick', 'Sjoblom', 'Pettersson', 'Yasbeck',
#        'Boulos', 'Lines', 'Aks', 'Najib', 'Graham'], dtype=object)

# %% [markdown]
# **12. ¿Cuales son los apellidos de los pasajeros que son hombres y mayor de 45 años?**

# %%
df[(df['Age'] > 20) & (df['Sex'] == 'male')]['last name'].unique()
# Out:
# array(['Braund', 'Allen', 'McCarthy', 'Andersson', 'Fynney', 'Beesley',
#        'Sloper', 'Uruchurtu', 'Wheadon', 'Meyer', 'Holverson', 'Cann',
#        'Nosworthy', 'Ostby', 'Novel', 'Sirayanian', 'Harris', 'Kink',
#        'Jenkin', 'Hood', 'Chronopoulos', 'Bing', 'Moen', 'Waelens',
#        'Sheerlinck', 'Carrau', 'Celotti', 'Christmann', 'Chaffee', 'Dean',
#        'Coxon', 'Goldschmidt', 'Greenfield', 'Kantor', 'White',
#        'Johansson', 'Gustafsson', 'Mionoff', 'Rekic', 'Porter', 'Barton',
#        'Pekoniemi', 'Connors', 'Turpin', 'Baxter', 'Hickman', 'Nasser',
#        'Madsen', 'Ekstrom', 'Drazenoic', 'Sobey', 'Richard', 'Futrelle',
#        'Giglio', 'Navratil', 'Byles', 'Bateman', 'Meo', 'van Billiard',
#        'Williams', 'Corn', 'Cribb', 'Bengtsson', 'Ling', 'Van der hoef',
#        'Sivola', 'Smith', 'Hale', 'Leonard', 'Romaine', 'Bourke',
#        'Turcin', 'Olsen', 'Vande Walle', 'Johanson', 'Youseff',
#        'Backstrom', 'Albimona', 'Blank', 'Ali', 'Perkin', 'Givard',
#        'Jacobsohn', 'Bracken', 'Green', 'Hoyt', 'Berglund', 'Lovell',
#        'Larsson', 'Sjostedt', 'Leyson', 'Hold', 'Hunt', 'Coleridge',
#        'Maenpaa', 'Attalah', 'Minahan', 'Beckwith', 'Carter', 'Stead',
#        'Lobb', 'Taussig', 'Harrison', 'Reeves', 'Persson', 'Tornquist',
#        'Natsch', 'Duane', 'Olsson', 'Stankovic', 'de Mulder', 'Naidenoff',
#        'Hosono', 'Levy', 'Mineff', 'Hanna', 'Abelson', 'Hendekovic',
#        'Hart', 'Moraweck', 'Dennis', 'Danoff', 'Nysveen', 'Partner',
#        'Graham', 'Pears', 'Dahl', 'Blackwell', 'Collander', 'Sedgwick',
#        'Fox', 'Dimic', 'Odahl', 'Arnold-Franchi', 'Vanden Steen', 'Skoog',
#        'del Carlo', 'Asim', 'Adahl', 'Harder', 'Ringhini', 'Widener',
#        'Tikkanen', 'Jansson', 'McKane', 'Pain', 'Niskanen', 'Adams',
#        'Hakkarainen', 'Gale', 'Widegren', 'Birkeland', 'Sundman',
#        'Matthews', 'Charters', 'Zimmerman', 'Pickard',
#        'Bjornstrom-Steffansson', 'Silvey', 'Fortune', 'Kvillner',
#        'Petterson', 'Seward', 'Peuchen', 'West', 'Foreman', 'Goldenberg',
#        'Jalsevac', 'Millet', 'Anderson', 'Morley', 'Gee', 'Milling',
#        'Goncalves', 'Smart', 'Cacic', 'Renouf', 'Karlsson', 'Rouse',
#        'Bishop', 'Kent', 'Somerton', 'Windelov', 'Molson', 'Artagaveytia',
#        'Stanley', 'Svensson', 'Lang', 'Daly', 'McGough', 'Coleff',
#        'Walker', 'Pavlovic', 'Vovk', 'Farrell', 'Salonen', 'Hocking',
#        'Butt', 'Beane', 'Douglas', 'Nicholson', 'Goldsmith', 'Sharp',
#        'Leeni', 'Wright', 'Sivic', 'Norman', 'Davies', 'Jonsson', 'Flynn',
#        'Jussila', 'Downton', 'Ross', 'Jarvis', 'Frolicher-Stehli',
#        'Gilinski', 'Rintamaki', 'Elsbury', 'Chapman', 'Van Impe',
#        'Johnson', 'Duff Gordon', 'Torber', 'Homer', 'Lindell', 'Karaic',
#        'Daniel', 'Brocklebank', 'Danbom', 'Gavey', 'Yasbeck', 'Kimball',
#        'Hansen', 'Bowen', 'Sutton', 'Kirkland', 'Bostandyeff',
#        'Barkworth', 'Lundahl', 'Stahelin-Maeglin', 'Leinonen', 'Collyer',
#        'Harper', 'Simonius-Blumer', 'Kalvik', 'Eitemiller', 'Newell',
#        'Frauenthal', 'Badt', 'Colley', 'Butler', 'Cook', 'Davidson',
#        'Mitchell', 'Wilhelms', 'Sawyer', 'Cardeza', 'Hassab', 'Brown',
#        'Laroche', 'Dick', 'Saad', 'Weir', 'Kelly', 'Thayer', 'Humblen',
#        'Silverthorne', 'Gallagher', 'Calderhead', 'Taylor', 'Greenberg',
#        'Gillespie', 'Hodges', 'Chambers', 'Bryhl', 'Berriman',
#        'Troupiansky', 'Lesurer', 'Cavendish', 'McNamee', 'Stranden',
#        'Crosby', 'Connaghton', 'Vande Velde', 'Jonkoff', 'Carlsson',
#        'Theobald', 'Nirva', 'Gronnestad', 'Lievens', 'Jensen', 'Long',
#        'Harmer', 'Guggenheim', 'Dantcheff', 'Otter', 'Ibrahim Shawah',
#        'Ponesell', 'Hedman', 'Andrews', 'Alexander', 'Lester', 'Slemen',
#        'Tomlin', 'Mallet', 'Holm', 'Lulic', 'Reuchlin', 'Augustsson',
#        'Pasic', 'Chip', 'Lemberopolous', 'Abbing', 'Markoff', 'Giles',
#        'Gill', 'Roebling', 'Balkic', 'Vander Cruyssen', 'Markun',
#        'Banfield', 'Sutehall', 'Montvila', 'Behr', 'Dooley'], dtype=object)

# %% [markdown]
# **13. Compara si coinciden los apellidos generados en los ejercicios anteriores**

# %% [markdown]
# **14. Encuentra los 10 pasajeros que no sobrevivieron más jovenes e imprime cuantos son hombres y cuantos son mujeres**

# %%
df_children = df.iloc[df['Age'].sort_values(ascending=True).head(10)]
df_children.groupby('Sex').size()
# Out:
# Sex
# female    3
# male      7
# dtype: int64

# %% [markdown]
# **15. En un dataframe muestra 3 pasajeros que sean hombres y 3 que sean mujeres, que hayan sobrevivido y para cada clase de la columna Pclass**

# %%
# Step 1: Filter passengers who survived
survived_passengers = df[df['Survived'] == 1]

# Step 2: Group by 'Pclass' and 'Sex', and select 3 males and 3 females for each class
result = survived_passengers.groupby(['Pclass', 'Sex']).head(3)

# Step 3: Sort the result to have a cleaner display (optional)
result = result.sort_values(by=['Pclass', 'Sex'])
result
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 23           24                       Sloper, Mr. William Thompson    male
# 55           56                                  Woolner, Mr. Hugh    male
# 97           98                    Greenfield, Mr. William Bertram    male
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   female
# 43           44           Laroche, Miss. Simonne Marie Anne Andree  female
# 17           18                       Williams, Mr. Charles Eugene    male
# 21           22                              Beesley, Mr. Lawrence    male
# 78           79                      Caldwell, Master. Alden Gates    male
# 2             3                             Heikkinen, Miss. Laina  female
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 36           37                                   Mamee, Mr. Hanna    male
# 65           66                           Moubarek, Master. Gerios    male
# 74           75                                      Bing, Mr. Lee    male
#
#       Age  PassengerId  Survived  Pclass            Ticket     Fare  \
# 1   38.00            2         1       1          PC 17599  71.2833
# 3   35.00            4         1       1            113803  53.1000
# 11  58.00           12         1       1            113783  26.5500
# 23  28.00           24         1       1            113788  35.5000
# 55    NaN           56         1       1             19947  35.5000
# 97  23.00           98         1       1          PC 17759  63.3583
# 9   14.00           10         1       2            237736  30.0708
# 15  55.00           16         1       2            248706  16.0000
# 43   3.00           44         1       2     SC/Paris 2123  41.5792
# 17    NaN           18         1       2            244373  13.0000
# 21  34.00           22         1       2            248698  13.0000
# 78   0.83           79         1       2            248738  29.0000
# 2   26.00            3         1       3  STON/O2. 3101282   7.9250
# 8   27.00            9         1       3            347742  11.1333
# 10   4.00           11         1       3           PP 9549  16.7000
# 36    NaN           37         1       3              2677   7.2292
# 65    NaN           66         1       3              2661  15.2458
# 74  32.00           75         1       3              1601  56.4958
#
#      last name
# 1      Cumings
# 3     Futrelle
# 11     Bonnell
# 23      Sloper
# 55     Woolner
# 97  Greenfield
# 9       Nasser
# 15     Hewlett
# 43     Laroche
# 17    Williams
# 21     Beesley
# 78    Caldwell
# 2    Heikkinen
# 8      Johnson
# 10   Sandstrom
# 36       Mamee
# 65    Moubarek
# 74        Bing

# %% [markdown]
# **16. Obtener el tipo de elementos de cada columna y convierte los que sean int64 a int32. Evalua la memoria que consume antes y después de convertir las columnas y comenta la diferencia**

# %% [markdown]
# **17. Encuentra a los pasajeros de la clase 1 y 3 entre 20 y 25 años y comprueba si son más hombres o mujeres**

# %% [markdown]
# **18. Agrega una nueva columna al daframe que se llame: "Rango edad" y va a catagorizar de la siguiente manera:**
# - Niño < 11 años
# - Joven <18 años
# - Adulto < 50 años
# - Mayor >= 50 años

# %%
# Step 1: Define a function to categorize age
def categorize_age(age):
    if pd.isna(age):  # Handle missing values
        return "Desconocido"
    elif age < 11:
        return "Niño"
    elif age < 18:
        return "Joven"
    elif age < 50:
        return "Adulto"
    else:
        return "Mayor"

# %%
# Step 2: Apply the function to create the new column 'Rango edad'
df['Rango edad'] = df['Age'].apply(categorize_age)
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  PassengerId  Survived  Pclass            Ticket     Fare  \
# 0    22.0            1         0       3         A/5 21171   7.2500
# 1    38.0            2         1       1          PC 17599  71.2833
# 2    26.0            3         1       3  STON/O2. 3101282   7.9250
# 3    35.0            4         1       1            113803  53.1000
# 4    35.0            5         0       3            373450   8.0500
# ..    ...          ...       ...     ...               ...      ...
# 886  27.0          887         0       2            211536  13.0000
# 887  19.0          888         1       1            112053  30.0000
# 888   NaN          889         0       3        W./C. 6607  23.4500
# 889  26.0          890         1       1            111369  30.0000
# 890  32.0          891         0       3            370376   7.7500
#
#      last name   Rango edad
# 0       Braund       Adulto
# 1      Cumings       Adulto
# 2    Heikkinen       Adulto
# 3     Futrelle       Adulto
# 4        Allen       Adulto
# ..         ...          ...
# 886   Montvila       Adulto
# 887     Graham       Adulto
# 888   Johnston  Desconocido
# 889       Behr       Adulto
# 890     Dooley       Adulto
#
# [891 rows x 11 columns]

# %% [markdown]
# **19. Encontrar a los pasajeros jovenes y mayores de la clase 2 y 3 que hayan sobrevivido. Imprimir los 10 primeros**

# %% [markdown]
# **20. Encuentra la edad promedio de todos los pasajeros y reemmplazala por los NaN en la columna de Age y ejecuta el ejercicio anterior**
# - Nota: para identificar un nan utilizaremos np.nan

# %% [markdown]
# **21. Cambia a español la columna Sex**

# %% [markdown]
# **22. Convierte a mayusculas todas las columnas que los valores sean cadenas**

# %% [markdown]
# **23. Agrupa por sexo y rango de edad y encuentra la edad promedio**

# %% [markdown]
# **24. Agrupa por sobrevivientes, sexo y encuentra la edad promedio**

# %% [markdown]
# **25. Divide la columna name en las siguientes columnas:**
#  - Mrs/Miss
#  - Apellido
#  - Nombre(s)
#
#
# Nota: Ignora el resto de información
